# %%
import sys
from pathlib import Path

# Automatically resolve the root directory and add 'src' to the Python path
ROOT_DIR = Path.cwd().parent
sys.path.append(str(ROOT_DIR / "src"))

# The Autoreload Holy Trinity
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
